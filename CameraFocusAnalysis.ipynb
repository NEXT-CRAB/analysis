# %%
import numpy
import sys, os
import matplotlib
import imageio

# %%
from matplotlib import pyplot as plt

# %%
file_name = "/home/cadams/Downloads/Capture1.PNG"

# %%
image = imageio.imread(file_name)
# Out:
# /tmp/ipykernel_60401/2741933642.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(file_name)

# %%
plt.imshow(image)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (503, 666, 4)

# %%
image[100,:,:]
# Out:
# array([[169, 169, 169, 255],
#        [166, 166, 166, 255],
#        [164, 164, 164, 255],
#        ...,
#        [ 25,  25,  25, 255],
#        [ 18,  18,  18, 255],
#        [ 14,  14,  14, 255]], dtype=uint8)

# %%
image_intensity = image[:,:,0]

# %%
target_data = image_intensity[200:350, 275]

x = numpy.arange(len(target_data))
y = target_data

fig = plt.figure(figsize=(16,9))
plt.plot(x,y)
plt.grid(True)
plt.show()

# %%
# !pip install imageio
# Out:
# Requirement already satisfied: imageio in /home/cadams/jax/lib/python3.10/site-packages (2.31.1)
# Requirement already satisfied: pillow>=8.3.2 in /home/cadams/jax/lib/python3.10/site-packages (from imageio) (9.5.0)
# Requirement already satisfied: numpy in /home/cadams/.local/lib/python3.10/site-packages/numpy-1.25.0rc1-py3.10-linux-x86_64.egg (from imageio) (1.25.0rc1)
